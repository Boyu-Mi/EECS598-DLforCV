# %% [markdown]
# # EECS 498-007/598-005 Assignment 2-2: Two Layer Neural Network
#
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Justin JOHNSON, #12345678

# %% [markdown]
# **Your Answer:**
# Your NAME, #XXXXXXXX

# %% [markdown]
# # Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as Assignment 1. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['two_layer_net.ipynb', 'eecs598', 'two_layer_net.py', 'linear_classifier.py', 'linear_classifier.ipynb', 'a2_helpers.py']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A2 folder, then '2020FA/A2'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A2'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'A2'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['a2_helpers.py', 'eecs598', '__pycache__', 'svm_best_model.pt', 'softmax_best_model.pt', 'linear_classifier.ipynb', 'linear_classifier.py', 'two_layer_net.ipynb', 'two_layer_net.py']

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from two_layer_net.py!
# Hello from a2_helpers.py!
# ```
#
# as well as the last edit time for the file `two_layer_net.py`.

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from two_layer_net import hello_two_layer_net
hello_two_layer_net()

from a2_helpers import hello_helper
hello_helper()

two_layer_net_path = os.path.join(GOOGLE_DRIVE_PATH, 'two_layer_net.py')
two_layer_net_edit_time = time.ctime(os.path.getmtime(two_layer_net_path))
print('two_layer_net.py last edited on %s' % two_layer_net_edit_time)
# Out:
# Hello from two_layer_net.py!
# Hello from a2_helpers.py!
# two_layer_net.py last edited on Sat Sep 17 20:58:17 2022

# %% [markdown]
# ## Miscellaneous

# %% [markdown]
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import eecs598
import torch
import matplotlib.pyplot as plt
import statistics
import random
import time
# %matplotlib inline


plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# We will use GPUs to accelerate our computation in this notebook. Run the following to make sure GPUs are enabled:

# %%
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.
#
# We train the network with a softmax loss function and L2 regularization on the weight matrices. The network uses a ReLU nonlinearity after the first fully connected layer.
#
# In other words, the network has the following architecture:
#
#   input - fully connected layer - ReLU - fully connected layer - softmax
#
# The outputs of the second fully-connected layer are the scores for each class.
#
# **Note**: When you implment the regularization over W, **please DO NOT multiply the regularization term by 1/2** (no coefficient).

# %% [markdown]
# ## Play with a toy data

# %% [markdown]
# The inputs to our network will be a batch of $N$ (`num_inputs`) $D$-dimensional vectors (`input_size`); the hidden layer will have $H$ hidden units (`hidden_size`), and we will predict classification scores for $C$ categories (`num_classes`). This means that the learnable weights and biases of the network will have the following shapes:
#
# *   W1: First layer weights; has shape (D, H)
# *   b1: First layer biases; has shape (H,)
# *   W2: Second layer weights; has shape (H, C)
# *   b2: Second layer biases; has shape (C,)
#
# We will use `a2_helpers.get_toy_data` function to generate random weights for a small toy model while we implement the model.

# %% [markdown]
# ### Forward pass: compute scores
# Like in the Linear Classifiers exercise, we want to write a function that takes as input the model weights and a batch of images and labels, and returns the loss and the gradient of the loss with respect to each model parameter.
#
# However rather than attempting to implement the entire function at once, we will take a staged approach and ask you to implement the full forward and backward pass one step at a time.
#
# First we will implement the forward pass of the network which uses the weights and biases to compute scores for all inputs in `nn_forward_pass`.

# %% [markdown]
# Compute the scores and compare with the answer. The distance gap should be smaller than 1e-10.

# %%
import eecs598
from a2_helpers import get_toy_data
from two_layer_net import nn_forward_pass

eecs598.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the score computation part of nn_forward_pass
scores, _ = nn_forward_pass(params, toy_X)
print('Your scores:')
print(scores)
print(scores.dtype)
print()
print('correct scores:')
correct_scores = torch.tensor([
        [ 9.7003e-08, -1.1143e-07, -3.9961e-08],
        [-7.4297e-08,  1.1502e-07,  1.5685e-07],
        [-2.5860e-07,  2.2765e-07,  3.2453e-07],
        [-4.7257e-07,  9.0935e-07,  4.0368e-07],
        [-1.8395e-07,  7.9303e-08,  6.0360e-07]], dtype=torch.float32, device=scores.device)
print(correct_scores)
print()

# The difference should be very small. We get < 1e-10
scores_diff = (scores - correct_scores).abs().sum().item()
print('Difference between your scores and correct scores: %.2e' % scores_diff)
# Out:
# Your scores:
# tensor([[ 9.7003e-08, -1.1143e-07, -3.9961e-08],
#         [-7.4297e-08,  1.1502e-07,  1.5685e-07],
#         [-2.5860e-07,  2.2765e-07,  3.2453e-07],
#         [-4.7257e-07,  9.0935e-07,  4.0368e-07],
#         [-1.8395e-07,  7.9303e-08,  6.0360e-07]], device='cuda:0')
# torch.float32
#
# correct scores:
# tensor([[ 9.7003e-08, -1.1143e-07, -3.9961e-08],
#         [-7.4297e-08,  1.1502e-07,  1.5685e-07],
#         [-2.5860e-07,  2.2765e-07,  3.2453e-07],
#         [-4.7257e-07,  9.0935e-07,  4.0368e-07],
#         [-1.8395e-07,  7.9303e-08,  6.0360e-07]], device='cuda:0')
#
# Difference between your scores and correct scores: 2.24e-11

# %% [markdown]
# ### Forward pass: compute loss
# Now, we implement the first part of `nn_forward_backward` that computes the data and regularization loss.
#
# For the data loss, we will use the softmax loss. For the regularization loss we will use L2 regularization on the weight matrices `W1` and `W2`; we will not apply regularization loss to the bias vectors `b1` and `b2`.

# %% [markdown]
# First, Let's run the following to check your implementation.
#
# We compute the loss for the toy data, and compare with the answer computed by our implementation. The difference between the correct and computed loss should be less than `1e-4`.

# %%
import eecs598
from a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward

eecs598.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the loss computation part of nn_forward_backward
loss, _ = nn_forward_backward(params, toy_X, toy_y, reg=0.05)
print('Your loss: ', loss.item())
correct_loss = 1.0986121892929077
print('Correct loss: ', correct_loss)
diff = (correct_loss - loss).item()

# should be very small, we get < 1e-4
print('Difference: %.4e' % diff)
# Out:
# Your loss:  1.0986121892929077
# Correct loss:  1.0986121892929077
# Difference: 0.0000e+00

# %% [markdown]
# ### Backward pass
# Now implement the backward pass for the entire network in `nn_forward_backward`.
#
# After doing so, we will use numeric gradient checking to see whether the analytic gradient computed by our backward pass mateches a numeric gradient.
#
# We will use the functions `eecs598.grad.compute_numeric_gradient` and `eecs598.grad.rel_error` to help with numeric gradient checking. We can learn more about these functions using the `help` command:

# %%
help(eecs598.grad.compute_numeric_gradient)
print('-' * 80)
help(eecs598.grad.rel_error)
# Out:
# Help on function compute_numeric_gradient in module eecs598.grad:
#
# compute_numeric_gradient(f, x, h=1e-07)
#     Compute the numeric gradient of f at x using a finite differences
#     approximation. We use the centered difference:
#
#     df    f(x + h) - f(x - h)
#     -- ~= -------------------
#     dx           2 * h
#
#     Inputs:
#     - f: A function that inputs a torch tensor and returns a torch scalar
#     - x: A torch tensor giving the point at which to compute the gradient
#
#     Returns:
#     - grad: A tensor of the same shape as x giving the gradient of f at x
#
# --------------------------------------------------------------------------------
# Help on function rel_error in module eecs598.grad:
#
# rel_error(x, y, eps=1e-10)
#     Compute the relative error between a pair of tensors x and y,
#     which is defined as:
#
#                             max_i |x_i - y_i]|
#     rel_error(x, y) = -------------------------------
#                       max_i |x_i| + max_i |y_i| + eps
#
#     Inputs:
#     - x, y: Tensors of the same shape
#     - eps: Small positive constant for numeric stability
#
#     Returns:
#     - rel_error: Scalar giving the relative error between x and y

# %% [markdown]
# Now we will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check.
#
# You should see relative errors less than `1e-4` for all parameters.

# %%
import eecs598
from a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward

eecs598.reset_seed(0)

reg = 0.05
toy_X, toy_y, params = get_toy_data(dtype=torch.float64)

# YOUR_TURN: Implement the gradient computation part of nn_forward_backward
#            When you implement the gradient computation part, you may need to 
#            implement the `hidden` output in nn_forward_pass, as well.
loss, grads = nn_forward_backward(params, toy_X, toy_y, reg=reg)

for param_name, grad in grads.items():
  param = params[param_name]
  f = lambda w: nn_forward_backward(params, toy_X, toy_y, reg=reg)[0]
  grad_numeric = eecs598.grad.compute_numeric_gradient(f, param)
  error = eecs598.grad.rel_error(grad, grad_numeric)
  print('%s max relative error: %e' % (param_name, error))
# Out:
# W1 max relative error: 1.441750e-06
# W2 max relative error: 1.261262e-06
# b1 max relative error: 8.239303e-06
# b2 max relative error: 3.122771e-09

# %% [markdown]
# ### Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers.
#
# Look at the function `nn_train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers.
#
# You will also have to implement `nn_predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. Your final training loss should be less than 1.0.

# %%
import eecs598
from a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward, nn_train, nn_predict

eecs598.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the nn_train function.
#            You may need to check nn_predict function (the "pred_func") as well.
stats = nn_train(params, nn_forward_backward, nn_predict, toy_X, toy_y, toy_X, toy_y,
                 learning_rate=1e-1, reg=1e-6,

                 num_iters=200, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'], 'o')
plt.xlabel('Iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.34914901852607727

# %%
# Plot the loss function and train / validation accuracies
plt.plot(stats['train_acc_history'], 'o', label='train')
plt.plot(stats['val_acc_history'], 'o', label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing our NN on a real dataset: CIFAR-10
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
import eecs598

# Invoke the above function to get our data.
eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to .
# Train data shape:  torch.Size([40000, 3072])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3072])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3072])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# ### Wrap all function into a Class
# We will use the class `TwoLayerNet` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are PyTorch tensors.

# %% [markdown]
# ### Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
import eecs598
from two_layer_net import TwoLayerNet

input_size = 3 * 32 * 32
hidden_size = 36
num_classes = 10

# fix random seed before we generate a set of parameters
eecs598.reset_seed(0)
net = TwoLayerNet(input_size, hidden_size, num_classes, dtype=data_dict['X_train'].dtype, device=data_dict['X_train'].device)

# Train the network
stats = net.train(data_dict['X_train'], data_dict['y_train'],
                  data_dict['X_val'], data_dict['y_val'],
                  num_iters=500, batch_size=1000,
                  learning_rate=1e-2, learning_rate_decay=0.95,
                  reg=0.25, verbose=True)

# Predict on the validation set
y_val_pred = net.predict(data_dict['X_val'])
val_acc = 100.0 * (y_val_pred == data_dict['y_val']).double().mean().item()
print('Validation accuracy: %.2f%%' % val_acc)
# Out:
# iteration 0 / 500: loss 2.302863
# iteration 100 / 500: loss 2.302727
# iteration 200 / 500: loss 2.302593
# iteration 300 / 500: loss 2.302561
# iteration 400 / 500: loss 2.302643
# Validation accuracy: 9.52%

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy less than 10% on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
from a2_helpers import plot_stats

plot_stats(stats)

# %% [markdown]
# Similar to SVM and Softmax classifier, let's visualize the weights.

# %%
from a2_helpers import show_net_weights 

show_net_weights(net)

# %% [markdown]
# ### What's wrong?
# Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.

# %% [markdown]
# #### Capacity?
# Our initial model has very similar performance on the training and validation sets. This suggests that the model is underfitting, and that its performance might improve if we were to increase its capacity.
#
# One way we can increase the capacity of a neural network model is to increase the size of its hidden layer. Here we investigate the effect of increasing the size of the hidden layer. The performance (as measured by validation-set accuracy) should increase as the size of the hidden layer increases; however it may show diminishing returns for larger layer sizes.

# %%
import eecs598
from a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hidden_sizes = [2, 8, 32, 128] 
lr = 0.1
reg = 0.001

stat_dict = {}
for hs in hidden_sizes:
  print('train with hidden size: {}'.format(hs))
  # fix random seed before we generate a set of parameters
  eecs598.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[hs] = stats

plot_acc_curves(stat_dict)
# Out:
# train with hidden size: 2
# train with hidden size: 8
# train with hidden size: 32
# train with hidden size: 128

# %% [markdown]
# #### Regularization?
# Another possible explanation for the small gap we saw between the train and validation accuracies of our model is regularization. In particular, if the regularization coefficient were too high then the model may be unable to fit the training data.
#
# We can investigate the phenomenon empirically by training a set of models with varying regularization strengths while fixing other hyperparameters.
#
# You should see that setting the regularization strength too high will harm the validation-set performance of the model:

# %%
import eecs598
from a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hs = 128
lr = 1.0
regs = [0, 1e-5, 1e-3, 1e-1]

stat_dict = {}
for reg in regs:
  print('train with regularization: {}'.format(reg))
  # fix random seed before we generate a set of parameters
  eecs598.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[reg] = stats

plot_acc_curves(stat_dict)
# Out:
# train with regularization: 0
# train with regularization: 1e-05
# train with regularization: 0.001
# train with regularization: 0.1

# %% [markdown]
# #### Learning Rate?
# Last but not least, we also want to see the effect of learning rate with respect to the performance.

# %%
import eecs598
from a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hs = 128
lrs = [1e-4, 1e-2, 1e0, 1e2]
reg = 1e-4

stat_dict = {}
for lr in lrs:
  print('train with learning rate: {}'.format(lr))
  # fix random seed before we generate a set of parameters
  eecs598.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[lr] = stats

plot_acc_curves(stat_dict)
# Out:
# train with learning rate: 0.0001
# train with learning rate: 0.01
# train with learning rate: 1.0
# train with learning rate: 100.0

# %% [markdown]
# ### Tune your hyperparameters
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, number of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Plots**. To guide your hyperparameter search, you might consider making auxiliary plots of training and validation performance as above, or plotting the results arising from different hyperparameter combinations as we did in the Linear Classifier notebook. You should feel free to plot any auxiliary results you need in order to find a good network, but we don't require any particular plots from you.
#
# **Approximate results**. To get full credit for the assignment, you should achieve a classification accuracy above 50% on the validation set.
#
# (Our best model gets a validation-set accuracy 56.44% -- did you beat us?)

# %%
import os
import eecs598
from two_layer_net import TwoLayerNet, find_best_net, nn_get_search_params

# running this model on float64 may needs more time, so set it as float32
eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(dtype=torch.float32)

# store the best model into this 
eecs598.reset_seed(0)
best_net, best_stat, best_val_acc = find_best_net(data_dict, nn_get_search_params)
print(best_val_acc)

plot_stats(best_stat)

# save the best model
path = os.path.join(GOOGLE_DRIVE_PATH, 'nn_best_model.pt')
best_net.save(path)
# Out:
# Training NN 1 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=3.200000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596647
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 2 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=3.200000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596647
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss 3.608197
# iteration 300 / 3000: loss 3.156492
# iteration 400 / 3000: loss 2.826459
# iteration 500 / 3000: loss 2.649244
# iteration 600 / 3000: loss 2.393103
# iteration 700 / 3000: loss 2.356755
# iteration 800 / 3000: loss 2.319167
# iteration 900 / 3000: loss 2.318235
# iteration 1000 / 3000: loss 2.173778
# iteration 1100 / 3000: loss 2.176612
# iteration 1200 / 3000: loss 2.131600
# iteration 1300 / 3000: loss 2.100106
# iteration 1400 / 3000: loss 2.079618
# iteration 1500 / 3000: loss 2.041037
# iteration 1600 / 3000: loss 2.027140
# iteration 1700 / 3000: loss 2.032090
# iteration 1800 / 3000: loss 1.992651
# iteration 1900 / 3000: loss 1.979088
# iteration 2000 / 3000: loss 1.956070
# iteration 2100 / 3000: loss 1.952926
# iteration 2200 / 3000: loss 1.976355
# iteration 2300 / 3000: loss 1.982484
# iteration 2400 / 3000: loss 1.988199
# iteration 2500 / 3000: loss 1.979575
# iteration 2600 / 3000: loss 1.959092
# iteration 2700 / 3000: loss 1.928006
# iteration 2800 / 3000: loss 1.971974
# iteration 2900 / 3000: loss 1.958715
# Validation accuracy: 34.04%
# Training NN 3 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=6.400000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596662
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 4 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=6.400000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596662
# iteration 100 / 3000: loss 2.008527
# iteration 200 / 3000: loss 1.974934
# iteration 300 / 3000: loss 1.645975
# iteration 400 / 3000: loss 1.530976
# iteration 500 / 3000: loss 1.527399
# iteration 600 / 3000: loss 1.449150
# iteration 700 / 3000: loss 1.434719
# iteration 800 / 3000: loss 1.501103
# iteration 900 / 3000: loss 1.437152
# iteration 1000 / 3000: loss 1.380578
# iteration 1100 / 3000: loss 1.377929
# iteration 1200 / 3000: loss 1.372134
# iteration 1300 / 3000: loss 1.317150
# iteration 1400 / 3000: loss 1.372936
# iteration 1500 / 3000: loss 1.293774
# iteration 1600 / 3000: loss 1.315055
# iteration 1700 / 3000: loss 1.336781
# iteration 1800 / 3000: loss 1.242521
# iteration 1900 / 3000: loss 1.248931
# iteration 2000 / 3000: loss 1.241133
# iteration 2100 / 3000: loss 1.280869
# iteration 2200 / 3000: loss 1.306760
# iteration 2300 / 3000: loss 1.297419
# iteration 2400 / 3000: loss 1.310736
# iteration 2500 / 3000: loss 1.289558
# iteration 2600 / 3000: loss 1.285787
# iteration 2700 / 3000: loss 1.242846
# iteration 2800 / 3000: loss 1.311577
# iteration 2900 / 3000: loss 1.278973
# Validation accuracy: 51.87%
# Training NN 5 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=1.280000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596690
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 6 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=1.280000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596690
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss 21734.023438
# iteration 900 / 3000: loss inf
# iteration 1000 / 3000: loss inf
# iteration 1100 / 3000: loss 15342.602539
# iteration 1200 / 3000: loss inf
# iteration 1300 / 3000: loss 12968.544922
# iteration 1400 / 3000: loss 12099.888672
# iteration 1500 / 3000: loss 11386.956055
# iteration 1600 / 3000: loss 10792.239258
# iteration 1700 / 3000: loss 10296.971680
# iteration 1800 / 3000: loss 9878.223633
# iteration 1900 / 3000: loss 9525.541992
# iteration 2000 / 3000: loss 9224.364258
# iteration 2100 / 3000: loss 8968.549805
# iteration 2200 / 3000: loss 8748.432617
# iteration 2300 / 3000: loss 8560.104492
# iteration 2400 / 3000: loss 8397.053711
# iteration 2500 / 3000: loss 8256.818359
# iteration 2600 / 3000: loss 8134.887207
# iteration 2700 / 3000: loss 8029.534180
# iteration 2800 / 3000: loss 7937.683594
# iteration 2900 / 3000: loss 7858.023926
# Validation accuracy: 34.31%
# Training NN 7 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=2.560000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596745
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 8 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-03, hidden_size=2.560000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596745
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss inf
# iteration 900 / 3000: loss 17321.794922
# iteration 1000 / 3000: loss inf
# iteration 1100 / 3000: loss inf
# iteration 1200 / 3000: loss 12746.511719
# iteration 1300 / 3000: loss 11784.785156
# iteration 1400 / 3000: loss 10995.829102
# iteration 1500 / 3000: loss 10348.339844
# iteration 1600 / 3000: loss 9808.090820
# iteration 1700 / 3000: loss 9358.263672
# iteration 1800 / 3000: loss 8977.800781
# iteration 1900 / 3000: loss 8657.384766
# iteration 2000 / 3000: loss 8383.736328
# iteration 2100 / 3000: loss 8151.487305
# iteration 2200 / 3000: loss 7951.579102
# iteration 2300 / 3000: loss 7780.499023
# iteration 2400 / 3000: loss 7632.377930
# iteration 2500 / 3000: loss 7505.004395
# iteration 2600 / 3000: loss 7394.147461
# iteration 2700 / 3000: loss 7298.442383
# iteration 2800 / 3000: loss 7214.914062
# iteration 2900 / 3000: loss 7142.573730
# Validation accuracy: 44.14%
# Training NN 9 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=3.200000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596635
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss 2204.789551
# iteration 900 / 3000: loss 2118.391602
# iteration 1000 / 3000: loss 2036.119019
# iteration 1100 / 3000: loss 1956.707642
# iteration 1200 / 3000: loss inf
# iteration 1300 / 3000: loss 1806.655884
# iteration 1400 / 3000: loss 1736.461792
# iteration 1500 / 3000: loss 1668.605957
# iteration 1600 / 3000: loss 1603.537109
# iteration 1700 / 3000: loss 1540.835083
# iteration 1800 / 3000: loss 1480.626953
# iteration 1900 / 3000: loss 1422.709717
# iteration 2000 / 3000: loss 1367.196167
# iteration 2100 / 3000: loss 1313.875244
# iteration 2200 / 3000: loss 1262.552246
# iteration 2300 / 3000: loss 1213.556396
# iteration 2400 / 3000: loss 1166.034058
# iteration 2500 / 3000: loss 1120.388306
# iteration 2600 / 3000: loss 1076.589722
# iteration 2700 / 3000: loss 1034.452393
# iteration 2800 / 3000: loss 993.977600
# iteration 2900 / 3000: loss 955.173889
# Validation accuracy: 9.53%
# Training NN 10 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=3.200000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596635
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss 2.365633
# iteration 300 / 3000: loss 2.200282
# iteration 400 / 3000: loss 2.075399
# iteration 500 / 3000: loss 2.063968
# iteration 600 / 3000: loss 1.963056
# iteration 700 / 3000: loss 1.977183
# iteration 800 / 3000: loss 2.017791
# iteration 900 / 3000: loss 2.027970
# iteration 1000 / 3000: loss 1.945073
# iteration 1100 / 3000: loss 1.968541
# iteration 1200 / 3000: loss 1.887700
# iteration 1300 / 3000: loss 1.924054
# iteration 1400 / 3000: loss 1.924808
# iteration 1500 / 3000: loss 1.888789
# iteration 1600 / 3000: loss 1.915854
# iteration 1700 / 3000: loss 1.899907
# iteration 1800 / 3000: loss 1.867308
# iteration 1900 / 3000: loss 1.827373
# iteration 2000 / 3000: loss 1.790790
# iteration 2100 / 3000: loss 1.806289
# iteration 2200 / 3000: loss 1.847582
# iteration 2300 / 3000: loss 1.874056
# iteration 2400 / 3000: loss 1.864552
# iteration 2500 / 3000: loss 1.847079
# iteration 2600 / 3000: loss 1.853138
# iteration 2700 / 3000: loss 1.814155
# iteration 2800 / 3000: loss 1.880172
# iteration 2900 / 3000: loss 1.881159
# Validation accuracy: 37.50%
# Training NN 11 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=6.400000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596637
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 12 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=6.400000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596637
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss 3.678051
# iteration 400 / 3000: loss 3.501009
# iteration 500 / 3000: loss 3.458858
# iteration 600 / 3000: loss 3.296838
# iteration 700 / 3000: loss 3.336483
# iteration 800 / 3000: loss 3.320174
# iteration 900 / 3000: loss 3.292808
# iteration 1000 / 3000: loss 3.209094
# iteration 1100 / 3000: loss 3.199698
# iteration 1200 / 3000: loss 3.171307
# iteration 1300 / 3000: loss 3.150165
# iteration 1400 / 3000: loss 3.142008
# iteration 1500 / 3000: loss 3.115910
# iteration 1600 / 3000: loss 3.108708
# iteration 1700 / 3000: loss 3.102440
# iteration 1800 / 3000: loss 3.071731
# iteration 1900 / 3000: loss 3.048285
# iteration 2000 / 3000: loss 3.018630
# iteration 2100 / 3000: loss 3.060147
# iteration 2200 / 3000: loss 3.037788
# iteration 2300 / 3000: loss 3.057681
# iteration 2400 / 3000: loss 3.054411
# iteration 2500 / 3000: loss 3.049609
# iteration 2600 / 3000: loss 3.048167
# iteration 2700 / 3000: loss 3.025239
# iteration 2800 / 3000: loss 3.069646
# iteration 2900 / 3000: loss 3.026377
# Validation accuracy: 37.07%
# Training NN 13 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=1.280000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596641
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 14 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=1.280000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596641
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss inf
# iteration 900 / 3000: loss inf
# iteration 1000 / 3000: loss inf
# iteration 1100 / 3000: loss inf
# iteration 1200 / 3000: loss inf
# iteration 1300 / 3000: loss inf
# iteration 1400 / 3000: loss inf
# iteration 1500 / 3000: loss inf
# iteration 1600 / 3000: loss inf
# iteration 1700 / 3000: loss inf
# iteration 1800 / 3000: loss inf
# iteration 1900 / 3000: loss inf
# iteration 2000 / 3000: loss inf
# iteration 2100 / 3000: loss inf
# iteration 2200 / 3000: loss inf
# iteration 2300 / 3000: loss inf
# iteration 2400 / 3000: loss inf
# iteration 2500 / 3000: loss inf
# iteration 2600 / 3000: loss inf
# iteration 2700 / 3000: loss inf
# iteration 2800 / 3000: loss inf
# iteration 2900 / 3000: loss 52213.648438
# Validation accuracy: 11.61%
# Training NN 15 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=2.560000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596645
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 16 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-04, hidden_size=2.560000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596645
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss inf
# iteration 900 / 3000: loss inf
# iteration 1000 / 3000: loss inf
# iteration 1100 / 3000: loss inf
# iteration 1200 / 3000: loss inf
# iteration 1300 / 3000: loss inf
# iteration 1400 / 3000: loss inf
# iteration 1500 / 3000: loss inf
# iteration 1600 / 3000: loss inf
# iteration 1700 / 3000: loss inf
# iteration 1800 / 3000: loss inf
# iteration 1900 / 3000: loss inf
# iteration 2000 / 3000: loss inf
# iteration 2100 / 3000: loss 22241.140625
# iteration 2200 / 3000: loss inf
# iteration 2300 / 3000: loss inf
# iteration 2400 / 3000: loss inf
# iteration 2500 / 3000: loss inf
# iteration 2600 / 3000: loss inf
# iteration 2700 / 3000: loss inf
# iteration 2800 / 3000: loss inf
# iteration 2900 / 3000: loss inf
# Validation accuracy: 38.84%
# Training NN 17 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=3.200000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss inf
# iteration 900 / 3000: loss inf
# iteration 1000 / 3000: loss inf
# iteration 1100 / 3000: loss inf
# iteration 1200 / 3000: loss inf
# iteration 1300 / 3000: loss inf
# iteration 1400 / 3000: loss 45957791744.000000
# iteration 1500 / 3000: loss 45773271040.000000
# iteration 1600 / 3000: loss 45590528000.000000
# iteration 1700 / 3000: loss 45409079296.000000
# iteration 1800 / 3000: loss 45227597824.000000
# iteration 1900 / 3000: loss inf
# iteration 2000 / 3000: loss inf
# iteration 2100 / 3000: loss inf
# iteration 2200 / 3000: loss inf
# iteration 2300 / 3000: loss 44358144000.000000
# iteration 2400 / 3000: loss inf
# iteration 2500 / 3000: loss 44003196928.000000
# iteration 2600 / 3000: loss inf
# iteration 2700 / 3000: loss inf
# iteration 2800 / 3000: loss inf
# iteration 2900 / 3000: loss 43315904512.000000
# Validation accuracy: 9.80%
# Training NN 18 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=3.200000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss 2.399409
# iteration 400 / 3000: loss 2.360901
# iteration 500 / 3000: loss 2.092404
# iteration 600 / 3000: loss 2.036101
# iteration 700 / 3000: loss 2.151396
# iteration 800 / 3000: loss 2.060771
# iteration 900 / 3000: loss 2.003703
# iteration 1000 / 3000: loss 1.994724
# iteration 1100 / 3000: loss 1.979607
# iteration 1200 / 3000: loss 1.973942
# iteration 1300 / 3000: loss 1.983353
# iteration 1400 / 3000: loss 1.974717
# iteration 1500 / 3000: loss 1.959608
# iteration 1600 / 3000: loss 1.977214
# iteration 1700 / 3000: loss 1.968963
# iteration 1800 / 3000: loss 1.937569
# iteration 1900 / 3000: loss 1.939520
# iteration 2000 / 3000: loss 1.929504
# iteration 2100 / 3000: loss 1.958989
# iteration 2200 / 3000: loss 1.962039
# iteration 2300 / 3000: loss 1.968219
# iteration 2400 / 3000: loss 1.936357
# iteration 2500 / 3000: loss 1.938707
# iteration 2600 / 3000: loss 1.942088
# iteration 2700 / 3000: loss 1.920031
# iteration 2800 / 3000: loss 1.973179
# iteration 2900 / 3000: loss 1.929583
# Validation accuracy: 23.48%
# Training NN 19 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=6.400000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 20 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=6.400000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss 9.705563
# iteration 800 / 3000: loss 9.493424
# iteration 900 / 3000: loss 9.453835
# iteration 1000 / 3000: loss 9.427509
# iteration 1100 / 3000: loss 9.379501
# iteration 1200 / 3000: loss 9.375870
# iteration 1300 / 3000: loss 9.370150
# iteration 1400 / 3000: loss 9.361482
# iteration 1500 / 3000: loss 9.319439
# iteration 1600 / 3000: loss 9.350422
# iteration 1700 / 3000: loss 9.319004
# iteration 1800 / 3000: loss 9.324264
# iteration 1900 / 3000: loss 9.350471
# iteration 2000 / 3000: loss 9.270884
# iteration 2100 / 3000: loss 9.296707
# iteration 2200 / 3000: loss 9.302901
# iteration 2300 / 3000: loss 9.307493
# iteration 2400 / 3000: loss 9.316227
# iteration 2500 / 3000: loss 9.282493
# iteration 2600 / 3000: loss 9.272708
# iteration 2700 / 3000: loss 9.256925
# iteration 2800 / 3000: loss 9.317438
# iteration 2900 / 3000: loss 9.268074
# Validation accuracy: 26.91%
# Training NN 21 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=1.280000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596636
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 22 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=1.280000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596636
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss inf
# iteration 500 / 3000: loss inf
# iteration 600 / 3000: loss inf
# iteration 700 / 3000: loss inf
# iteration 800 / 3000: loss inf
# iteration 900 / 3000: loss inf
# iteration 1000 / 3000: loss inf
# iteration 1100 / 3000: loss inf
# iteration 1200 / 3000: loss inf
# iteration 1300 / 3000: loss inf
# iteration 1400 / 3000: loss inf
# iteration 1500 / 3000: loss inf
# iteration 1600 / 3000: loss inf
# iteration 1700 / 3000: loss inf
# iteration 1800 / 3000: loss inf
# iteration 1900 / 3000: loss 5760.131836
# iteration 2000 / 3000: loss inf
# iteration 2100 / 3000: loss inf
# iteration 2200 / 3000: loss inf
# iteration 2300 / 3000: loss inf
# iteration 2400 / 3000: loss inf
# iteration 2500 / 3000: loss inf
# iteration 2600 / 3000: loss inf
# iteration 2700 / 3000: loss inf
# iteration 2800 / 3000: loss inf
# iteration 2900 / 3000: loss inf
# Validation accuracy: 20.53%
# Training NN 23 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=2.560000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596635
# iteration 100 / 3000: loss inf
# iteration 200 / 3000: loss inf
# iteration 300 / 3000: loss inf
# iteration 400 / 3000: loss nan
# iteration 500 / 3000: loss nan
# iteration 600 / 3000: loss nan
# iteration 700 / 3000: loss nan
# iteration 800 / 3000: loss nan
# iteration 900 / 3000: loss nan
# iteration 1000 / 3000: loss nan
# iteration 1100 / 3000: loss nan
# iteration 1200 / 3000: loss nan
# iteration 1300 / 3000: loss nan
# iteration 1400 / 3000: loss nan
# iteration 1500 / 3000: loss nan
# iteration 1600 / 3000: loss nan
# iteration 1700 / 3000: loss nan
# iteration 1800 / 3000: loss nan
# iteration 1900 / 3000: loss nan
# iteration 2000 / 3000: loss nan
# iteration 2100 / 3000: loss nan
# iteration 2200 / 3000: loss nan
# iteration 2300 / 3000: loss nan
# iteration 2400 / 3000: loss nan
# iteration 2500 / 3000: loss nan
# iteration 2600 / 3000: loss nan
# iteration 2700 / 3000: loss nan
# iteration 2800 / 3000: loss nan
# iteration 2900 / 3000: loss nan
# Validation accuracy: 10.14%
# Training NN 24 / 48 with learning_rate=1.000000e+00 and reg=1.000000e-05, hidden_size=2.560000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596635
# iteration 100 / 3000: loss 1.809799
# iteration 200 / 3000: loss 1.628696
# iteration 300 / 3000: loss 1.399784
# iteration 400 / 3000: loss 1.395652
# iteration 500 / 3000: loss 1.243174
# iteration 600 / 3000: loss 1.195114
# iteration 700 / 3000: loss 1.120248
# iteration 800 / 3000: loss 1.147859
# iteration 900 / 3000: loss 1.071265
# iteration 1000 / 3000: loss 1.024771
# iteration 1100 / 3000: loss 0.988897
# iteration 1200 / 3000: loss 0.979226
# iteration 1300 / 3000: loss 0.910002
# iteration 1400 / 3000: loss 0.945828
# iteration 1500 / 3000: loss 0.850255
# iteration 1600 / 3000: loss 0.868485
# iteration 1700 / 3000: loss 0.848342
# iteration 1800 / 3000: loss 0.780292
# iteration 1900 / 3000: loss 0.804988
# iteration 2000 / 3000: loss 0.768513
# iteration 2100 / 3000: loss 0.771907
# iteration 2200 / 3000: loss 0.810028
# iteration 2300 / 3000: loss 0.797807
# iteration 2400 / 3000: loss 0.838753
# iteration 2500 / 3000: loss 0.754066
# iteration 2600 / 3000: loss 0.782156
# iteration 2700 / 3000: loss 0.757858
# iteration 2800 / 3000: loss 0.806746
# iteration 2900 / 3000: loss 0.764030
# Validation accuracy: 52.74%
# Training NN 25 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-03, hidden_size=3.200000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596647
# iteration 100 / 3000: loss 4.238162
# iteration 200 / 3000: loss 2.652076
# iteration 300 / 3000: loss 2.181888
# iteration 400 / 3000: loss 1.928642
# iteration 500 / 3000: loss 1.904214
# iteration 600 / 3000: loss 1.769992
# iteration 700 / 3000: loss 1.758279
# iteration 800 / 3000: loss 1.789317
# iteration 900 / 3000: loss 1.748908
# iteration 1000 / 3000: loss 1.659303
# iteration 1100 / 3000: loss 1.679748
# iteration 1200 / 3000: loss 1.656047
# iteration 1300 / 3000: loss 1.630153
# iteration 1400 / 3000: loss 1.615211
# iteration 1500 / 3000: loss 1.571090
# iteration 1600 / 3000: loss 1.577281
# iteration 1700 / 3000: loss 1.633244
# iteration 1800 / 3000: loss 1.511701
# iteration 1900 / 3000: loss 1.496063
# iteration 2000 / 3000: loss 1.512182
# iteration 2100 / 3000: loss 1.491101
# iteration 2200 / 3000: loss 1.522903
# iteration 2300 / 3000: loss 1.545005
# iteration 2400 / 3000: loss 1.527578
# iteration 2500 / 3000: loss 1.539717
# iteration 2600 / 3000: loss 1.518149
# iteration 2700 / 3000: loss 1.474456
# iteration 2800 / 3000: loss 1.516920
# iteration 2900 / 3000: loss 1.494201
# Validation accuracy: 46.28%
# Training NN 26 / 48 with learning_rate=1.000000e-01 and reg=1.000000e
and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596645
# iteration 100 / 3000: loss 3.792929
# iteration 200 / 3000: loss 2.507664
# iteration 300 / 3000: loss 2.150800
# iteration 400 / 3000: loss 1.903347
# iteration 500 / 3000: loss 1.915485
# iteration 600 / 3000: loss 1.803065
# iteration 700 / 3000: loss 1.795493
# iteration 800 / 3000: loss 1.819604
# iteration 900 / 3000: loss 1.820122
# iteration 1000 / 3000: loss 1.740937
# iteration 1100 / 3000: loss 1.766514
# iteration 1200 / 3000: loss 1.731832
# iteration 1300 / 3000: loss 1.732183
# iteration 1400 / 3000: loss 1.731408
# iteration 1500 / 3000: loss 1.682694
# iteration 1600 / 3000: loss 1.695604
# iteration 1700 / 3000: loss 1.736561
# iteration 1800 / 3000: loss 1.668998
# iteration 1900 / 3000: loss 1.612529
# iteration 2000 / 3000: loss 1.652063
# iteration 2100 / 3000: loss 1.607859
# iteration 2200 / 3000: loss 1.671000
# iteration 2300 / 3000: loss 1.700600
# iteration 2400 / 3000: loss 1.671622
# iteration 2500 / 3000: loss 1.654283
# iteration 2600 / 3000: loss 1.648221
# iteration 2700 / 3000: loss 1.608087
# iteration 2800 / 3000: loss 1.641559
# iteration 2900 / 3000: loss 1.656983
# Validation accuracy: 40.46%
# Training NN 41 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=3.200000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss 4.215734
# iteration 200 / 3000: loss 2.424452
# iteration 300 / 3000: loss 2.135894
# iteration 400 / 3000: loss 1.876012
# iteration 500 / 3000: loss 1.840272
# iteration 600 / 3000: loss 1.703832
# iteration 700 / 3000: loss 1.690632
# iteration 800 / 3000: loss 1.718678
# iteration 900 / 3000: loss 1.676908
# iteration 1000 / 3000: loss 1.585174
# iteration 1100 / 3000: loss 1.603332
# iteration 1200 / 3000: loss 1.573684
# iteration 1300 / 3000: loss 1.548861
# iteration 1400 / 3000: loss 1.531810
# iteration 1500 / 3000: loss 1.487623
# iteration 1600 / 3000: loss 1.492484
# iteration 1700 / 3000: loss 1.545856
# iteration 1800 / 3000: loss 1.416592
# iteration 1900 / 3000: loss 1.396960
# iteration 2000 / 3000: loss 1.406967
# iteration 2100 / 3000: loss 1.396736
# iteration 2200 / 3000: loss 1.423927
# iteration 2300 / 3000: loss 1.438653
# iteration 2400 / 3000: loss 1.422942
# iteration 2500 / 3000: loss 1.431338
# iteration 2600 / 3000: loss 1.400279
# iteration 2700 / 3000: loss 1.375076
# iteration 2800 / 3000: loss 1.408396
# iteration 2900 / 3000: loss 1.368545
# Validation accuracy: 46.75%
# Training NN 42 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=3.200000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss 5.525464
# iteration 200 / 3000: loss 2.555218
# iteration 300 / 3000: loss 2.195524
# iteration 400 / 3000: loss 1.960746
# iteration 500 / 3000: loss 1.966956
# iteration 600 / 3000: loss 1.840420
# iteration 700 / 3000: loss 1.842685
# iteration 800 / 3000: loss 1.845867
# iteration 900 / 3000: loss 1.852117
# iteration 1000 / 3000: loss 1.779548
# iteration 1100 / 3000: loss 1.793515
# iteration 1200 / 3000: loss 1.761888
# iteration 1300 / 3000: loss 1.763172
# iteration 1400 / 3000: loss 1.752546
# iteration 1500 / 3000: loss 1.702953
# iteration 1600 / 3000: loss 1.723776
# iteration 1700 / 3000: loss 1.766838
# iteration 1800 / 3000: loss 1.701904
# iteration 1900 / 3000: loss 1.646540
# iteration 2000 / 3000: loss 1.678496
# iteration 2100 / 3000: loss 1.620347
# iteration 2200 / 3000: loss 1.699842
# iteration 2300 / 3000: loss 1.717115
# iteration 2400 / 3000: loss 1.701585
# iteration 2500 / 3000: loss 1.671678
# iteration 2600 / 3000: loss 1.666110
# iteration 2700 / 3000: loss 1.621024
# iteration 2800 / 3000: loss 1.671664
# iteration 2900 / 3000: loss 1.691511
# Validation accuracy: 39.59%
# Training NN 43 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=6.400000e+01 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss 4.046862
# iteration 200 / 3000: loss 2.516884
# iteration 300 / 3000: loss 2.063947
# iteration 400 / 3000: loss 1.837962
# iteration 500 / 3000: loss 1.816705
# iteration 600 / 3000: loss 1.696806
# iteration 700 / 3000: loss 1.685179
# iteration 800 / 3000: loss 1.721260
# iteration 900 / 3000: loss 1.679838
# iteration 1000 / 3000: loss 1.590526
# iteration 1100 / 3000: loss 1.598754
# iteration 1200 / 3000: loss 1.570353
# iteration 1300 / 3000: loss 1.530672
# iteration 1400 / 3000: loss 1.512293
# iteration 1500 / 3000: loss 1.464625
# iteration 1600 / 3000: loss 1.460735
# iteration 1700 / 3000: loss 1.492928
# iteration 1800 / 3000: loss 1.376367
# iteration 1900 / 3000: loss 1.365111
# iteration 2000 / 3000: loss 1.377695
# iteration 2100 / 3000: loss 1.352996
# iteration 2200 / 3000: loss 1.375299
# iteration 2300 / 3000: loss 1.382581
# iteration 2400 / 3000: loss 1.382267
# iteration 2500 / 3000: loss 1.362978
# iteration 2600 / 3000: loss 1.334967
# iteration 2700 / 3000: loss 1.293403
# iteration 2800 / 3000: loss 1.321990
# iteration 2900 / 3000: loss 1.296745
# Validation accuracy: 48.70%
# Training NN 44 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=6.400000e+01 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596634
# iteration 100 / 3000: loss 4.663474
# iteration 200 / 3000: loss 2.835945
# iteration 300 / 3000: loss 2.153370
# iteration 400 / 3000: loss 1.916538
# iteration 500 / 3000: loss 1.925283
# iteration 600 / 3000: loss 1.811528
# iteration 700 / 3000: loss 1.814772
# iteration 800 / 3000: loss 1.832467
# iteration 900 / 3000: loss 1.831524
# iteration 1000 / 3000: loss 1.757229
# iteration 1100 / 3000: loss 1.776363
# iteration 1200 / 3000: loss 1.743166
# iteration 1300 / 3000: loss 1.745677
# iteration 1400 / 3000: loss 1.747639
# iteration 1500 / 3000: loss 1.695758
# iteration 1600 / 3000: loss 1.704172
# iteration 1700 / 3000: loss 1.739495
# iteration 1800 / 3000: loss 1.679736
# iteration 1900 / 3000: loss 1.629696
# iteration 2000 / 3000: loss 1.653971
# iteration 2100 / 3000: loss 1.621311
# iteration 2200 / 3000: loss 1.678537
# iteration 2300 / 3000: loss 1.706742
# iteration 2400 / 3000: loss 1.678187
# iteration 2500 / 3000: loss 1.665761
# iteration 2600 / 3000: loss 1.658100
# iteration 2700 / 3000: loss 1.618863
# iteration 2800 / 3000: loss 1.653638
# iteration 2900 / 3000: loss 1.673038
# Validation accuracy: 39.63%
# Training NN 45 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=1.280000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596636
# iteration 100 / 3000: loss 3.642696
# iteration 200 / 3000: loss 2.444910
# iteration 300 / 3000: loss 2.050935
# iteration 400 / 3000: loss 1.826591
# iteration 500 / 3000: loss 1.801739
# iteration 600 / 3000: loss 1.684638
# iteration 700 / 3000: loss 1.667683
# iteration 800 / 3000: loss 1.708971
# iteration 900 / 3000: loss 1.664828
# iteration 1000 / 3000: loss 1.574582
# iteration 1100 / 3000: loss 1.576851
# iteration 1200 / 3000: loss 1.547789
# iteration 1300 / 3000: loss 1.509786
# iteration 1400 / 3000: loss 1.503747
# iteration 1500 / 3000: loss 1.427994
# iteration 1600 / 3000: loss 1.427283
# iteration 1700 / 3000: loss 1.470472
# iteration 1800 / 3000: loss 1.351255
# iteration 1900 / 3000: loss 1.337724
# iteration 2000 / 3000: loss 1.335146
# iteration 2100 / 3000: loss 1.309786
# iteration 2200 / 3000: loss 1.335372
# iteration 2300 / 3000: loss 1.341818
# iteration 2400 / 3000: loss 1.342672
# iteration 2500 / 3000: loss 1.324557
# iteration 2600 / 3000: loss 1.306490
# iteration 2700 / 3000: loss 1.242210
# iteration 2800 / 3000: loss 1.280095
# iteration 2900 / 3000: loss 1.248544
# Validation accuracy: 49.77%
# Training NN 46 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=1.280000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596636
# iteration 100 / 3000: loss 4.088325
# iteration 200 / 3000: loss 2.651481
# iteration 300 / 3000: loss 2.145369
# iteration 400 / 3000: loss 1.902352
# iteration 500 / 3000: loss 1.913053
# iteration 600 / 3000: loss 1.799360
# iteration 700 / 3000: loss 1.793241
# iteration 800 / 3000: loss 1.817792
# iteration 900 / 3000: loss 1.815394
# iteration 1000 / 3000: loss 1.736955
# iteration 1100 / 3000: loss 1.763964
# iteration 1200 / 3000: loss 1.730044
# iteration 1300 / 3000: loss 1.725813
# iteration 1400 / 3000: loss 1.727935
# iteration 1500 / 3000: loss 1.675955
# iteration 1600 / 3000: loss 1.693887
# iteration 1700 / 3000: loss 1.727090
# iteration 1800 / 3000: loss 1.664762
# iteration 1900 / 3000: loss 1.611541
# iteration 2000 / 3000: loss 1.642179
# iteration 2100 / 3000: loss 1.597384
# iteration 2200 / 3000: loss 1.665567
# iteration 2300 / 3000: loss 1.696065
# iteration 2400 / 3000: loss 1.665682
# iteration 2500 / 3000: loss 1.651467
# iteration 2600 / 3000: loss 1.642088
# iteration 2700 / 3000: loss 1.602835
# iteration 2800 / 3000: loss 1.636567
# iteration 2900 / 3000: loss 1.649169
# Validation accuracy: 40.29%
# Training NN 47 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=2.560000e+02 and lr_decay=1.000000e+00
# iteration 0 / 3000: loss 10.596635
# iteration 100 / 3000: loss 3.534584
# iteration 200 / 3000: loss 2.509666
# iteration 300 / 3000: loss 2.049143
# iteration 400 / 3000: loss 1.816837
# iteration 500 / 3000: loss 1.801452
# iteration 600 / 3000: loss 1.679330
# iteration 700 / 3000: loss 1.661410
# iteration 800 / 3000: loss 1.700684
# iteration 900 / 3000: loss 1.657079
# iteration 1000 / 3000: loss 1.565540
# iteration 1100 / 3000: loss 1.567031
# iteration 1200 / 3000: loss 1.537996
# iteration 1300 / 3000: loss 1.499736
# iteration 1400 / 3000: loss 1.486926
# iteration 1500 / 3000: loss 1.423216
# iteration 1600 / 3000: loss 1.401144
# iteration 1700 / 3000: loss 1.448879
# iteration 1800 / 3000: loss 1.332645
# iteration 1900 / 3000: loss 1.317964
# iteration 2000 / 3000: loss 1.311098
# iteration 2100 / 3000: loss 1.289623
# iteration 2200 / 3000: loss 1.307507
# iteration 2300 / 3000: loss 1.320695
# iteration 2400 / 3000: loss 1.313034
# iteration 2500 / 3000: loss 1.284143
# iteration 2600 / 3000: loss 1.253670
# iteration 2700 / 3000: loss 1.218812
# iteration 2800 / 3000: loss 1.237298
# iteration 2900 / 3000: loss 1.193911
# Validation accuracy: 50.64%
# Training NN 48 / 48 with learning_rate=1.000000e-01 and reg=1.000000e-05, hidden_size=2.560000e+02 and lr_decay=9.500000e-01
# iteration 0 / 3000: loss 10.596635
# iteration 100 / 3000: loss 3.792884
# iteration 200 / 3000: loss 2.454766
# iteration 300 / 3000: loss 2.144527
# iteration 400 / 3000: loss 1.897565
# iteration 500 / 3000: loss 1.909249
# iteration 600 / 3000: loss 1.796548
# iteration 700 / 3000: loss 1.788600
# iteration 800 / 3000: loss 1.812858
# iteration 900 / 3000: loss 1.813100
# iteration 1000 / 3000: loss 1.733990
# iteration 1100 / 3000: loss 1.759340
# iteration 1200 / 3000: loss 1.724685
# iteration 1300 / 3000: loss 1.725094
# iteration 1400 / 3000: loss 1.723978
# iteration 1500 / 3000: loss 1.675471
# iteration 1600 / 3000: loss 1.688190
# iteration 1700 / 3000: loss 1.729274
# iteration 1800 / 3000: loss 1.661833
# iteration 1900 / 3000: loss 1.604489
# iteration 2000 / 3000: loss 1.644751
# iteration 2100 / 3000: loss 1.600276
# iteration 2200 / 3000: loss 1.663696
# iteration 2300 / 3000: loss 1.693425
# iteration 2400 / 3000: loss 1.663989
# iteration 2500 / 3000: loss 1.647137
# iteration 2600 / 3000: loss 1.640558
# iteration 2700 / 3000: loss 1.600181
# iteration 2800 / 3000: loss 1.634153
# iteration 2900 / 3000: loss 1.649275
# Validation accuracy: 40.40%
# 52.739999999999995
# Saved in drive/My Drive/A2/nn_best_model.pt

# %%
# Check the validation-set accuracy of your best model
y_val_preds = best_net.predict(data_dict['X_val'])
val_acc = 100 * (y_val_preds == data_dict['y_val']).double().mean().item()
print('Best val-set accuracy: %.2f%%' % val_acc)
# Out:
# Best val-set accuracy: 10.14%

# %%
from a2_helpers import show_net_weights
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# ### Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set. To get full credit for the assignment, you should achieve over 50% classification accuracy on the test set.
#
# (Our best model gets 56.03% test-set accuracy -- did you beat us?)

# %%
y_test_preds = best_net.predict(data_dict['X_test'])
test_acc = 100 * (y_test_preds == data_dict['y_test']).double().mean().item()
print('Test accuracy: %.2f%%' % test_acc)

# %% [markdown]
# # Submit Your Work
# After completing both notebooks for this assignment (`linear_classifier.ipynb` and this notebook, `two_layer_net.ipynb`), run the following cell to create a `.zip` file for you to download and turn in. **Please MANUALLY SAVE every `*.ipynb` and `*.py` files before executing the following cell:**

# %%
from eecs598.submit import make_a2_submission

# TODO: Replace these with your actual uniquename and umid
uniquename = None
umid = None
make_a2_submission(GOOGLE_DRIVE_PATH, uniquename, umid)
